# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import torch
import time

# %%
from bgforces.ala2 import Ala2Generator

# %%
MODEL = "Bspline+FM270918"
CHECKPOINT = "logs/a2_1/version_33/checkpoints/epoch=9-step=70320.ckpt"
loaded = Ala2Generator.load_from_checkpoint(
    CHECKPOINT
)
# Out:
# /home/sonic/ICL_SMH/Research/SmoothNFcopy0707_codeOpt/bgflow/bgflow/distribution/energy/openmm.py:215: UserWarning: It looks like you are using an OpenMMBridge with multiple workers in an ipython environment. This can behave a bit silly upon KeyboardInterrupt (e.g., kill the stdout stream). If you experience any issues, consider initializing the bridge with n_workers=1 in ipython/jupyter.
#   warnings.warn(

# %%
sum( np.prod(p.shape) for p in loaded.parameters())
# Out:
# 380982

# %%
from bgforces.ala2 import Ala2Data
data = Ala2Data(batch_size=128, slice=10)
data.prepare_data()
data.setup()

# %% [markdown]
# # Skip This if data has already been generated:

# %%
tolist = lambda x: list(x.detach().numpy())

# %%
from tqdm.notebook import tqdm

# %%
class BG:
    samples = []
    model_energies = []
    target_energies = []
    model_forces = []
    target_forces = []
    start = time.time()  # 시작 시간 저장
    for i in tqdm(range(100)):
        _samples = loaded.model.sample(100)
        samples.append(tolist(_samples))
        model_energies.append(tolist(loaded.model.energy(_samples)[:,0]))
        target_energies.append(tolist(loaded.model._target.energy(_samples)[:,0]))
        model_forces.append(tolist(loaded.model.force(_samples)))
        target_forces.append(tolist(loaded.model._target.force(_samples)))
    print("sampling time per sample (ms):", (time.time() - start)/10)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# tensor(3.5335, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.0264, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(3.7087, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7706, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(1.9749, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.3638, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(0.6582, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.1085, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(2.3169, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.0944, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(2.7137, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7671, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# /home/sonic/anaconda3/envs/B_spline_flows_codeopt/lib/python3.8/site-packages/torch/_tensor.py:1104: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the .grad field to be populated for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations. (Triggered internally at  /opt/conda/conda-bld/pytorch_1646755903507/work/build/aten/src/ATen/core/TensorBody.h:475.)
#   return self._grad
# tensor(3.6038, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.0077, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(2.2029, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7569, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(3.6985, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.8471, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(0.8459, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.1647, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(3.8124, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.0901, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(4.6282, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7677, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(4.5235, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-2.9401, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(2.3885, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7686, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(2.0886, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.3619, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(0.5666, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.8059, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(4.2843, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.1190, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(3.1180, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7703, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(2.1989, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.0084, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(3.9190, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7850, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(3.2147, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-2.0352, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(0.5113, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.0483, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(6.9124, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.0670, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(3.6928, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7722, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(3.8347, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.0371, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(4.9644, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7641, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(2.0174, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.3768, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(0.7102, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.0512, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(1.8825, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.0625, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(4.6232, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7721, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(4.2906, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.0127, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(2.6985, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7429, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(2.0988, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.3738, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(0.7375, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.0812, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(3.5038, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.0970, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(3.1488, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7687, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(6.8709, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.0306, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(2.5530, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7303, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(2.0132, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.4240, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(0.4499, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.2616, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(2.8684, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.1771, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(2.9051, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7654, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(3.4972, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.0520, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(2.6505, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7693, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(3.7069, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.3605, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(0.7883, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.0516, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(6.3458, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.1583, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(3.2944, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7663, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(3.2698, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-2.9943, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(2.5821, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7352, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(3.1137, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.3596, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(0.4812, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.1169, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(2.8609, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.0770, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(10.4120, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7745, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(4.1504, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.0297, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(2.7717, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7667, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(1.9513, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.3825, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(0.7614, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.0731, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(9.4906, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.1033, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(3.4433, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7622, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(5.1517, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.0441, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(4.0985, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7793, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(1.9272, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.3706, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(0.5733, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.5607, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(2.9280, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.0921, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(6.2671, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7630, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(3.8712, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.0252, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(4.1764, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7720, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(2.2896, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.3668, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(0.6998, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.2275, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(3.1038, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.0640, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(1.1696, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7646, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(5.2293, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.0255, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(2.9806, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7587, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(3.3620, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.3717, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(0.5260, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.7422, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(4.1966, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.1145, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(2.5038, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7621, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(5.4635, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.0236, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(3.2094, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7602, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(1.9108, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.3811, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(0.5564, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.0398, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(4.5413, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.
dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.2455, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(7.0516, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.1247, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(3.4725, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7741, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(3.6016, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.0567, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(10.3668, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7926, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(3.1445, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.9546, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(0.5701, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.0730, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(5.4894, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.1362, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(3.3861, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7683, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(3.1531, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.0245, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(4.7948, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7529, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(3.4519, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.3672, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(0.7729, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.0552, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(3.7316, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.1819, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(2.0107, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7743, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(4.7717, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.0147, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(3.9177, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7837, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(2.0268, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.3727, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(0.5645, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.1087, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(4.6390, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.0906, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(3.2419, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7686, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(6.1128, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.0600, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(2.0930, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7109, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(3.1198, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.6906, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(0.5083, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.0680, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(5.2336, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.0930, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(5.1371, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7630, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(3.4169, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.0029, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(2.5814, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7151, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(2.8512, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.3650, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(0.5750, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.0468, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(10.5021, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.0675, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(2.2923, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7693, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(2.9372, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-2.9624, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(3.9503, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7069, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(2.9634, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.3655, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(0.7925, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.5262, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(4.9728, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.0957, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(1.6136, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7764, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(4.0546, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.0539, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(3.6476, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.6550, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(2.8361, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.3637, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(0.6513, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.2375, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(3.1878, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.0802, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(2.4087, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7715, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(5.6639, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.0320, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(3.6450, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7559, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(1.7968, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.3690, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(0.5215, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.5193, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(2.4470, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.0877, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(3.2329, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7727, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(3.4223, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-2.9794, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(3.3940, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7343, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(3.7345, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.3661, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(0.4309, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.0535, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(5.1690, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.0752, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(3.1603, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7684, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(3.8657, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-2.9399, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(5.7626, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7286, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(2.0535, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-2.0953, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(0.7662, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.1133, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(4.6032, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.0839, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(3.5801, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7736, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# sampling time per sample (ms): 1.6635676622390747

# %%
np.savez(
    f"bg_samples_{MODEL.lower()}.npz", 
    samples=np.array(BG.samples),
    model_energies=np.array(BG.model_energies),
    target_energies=np.array(BG.target_energies),
    model_forces=np.array(BG.model_forces),
    target_forces=np.array(BG.target_forces)
)

# %%
class DATA:
    samples = []
    model_energies = []
    target_energies = []
    model_forces = []
    target_forces = []
    start = time.time()
    for i in tqdm(range(100)):
        _samples = data.val_xyz[100*i:100*(i+1)]
        samples.append(tolist(_samples))
        model_energies.append(tolist(loaded.model.energy(_samples)[:,0]))
        target_energies.append(tolist(loaded.model._target.energy(_samples)[:,0]))
        model_forces.append(tolist(loaded.model.force(_samples)))
        target_forces.append(tolist(loaded.model._target.force(_samples)))
    print("density estimation time per sample (ms):", (time.time() - start)/10)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# density estimation time per sample (ms): 1.0495689630508422

# %%
np.savez(
    f"data_samples_{MODEL.lower()}.npz", 
    samples=np.array(DATA.samples),
    model_energies=np.array(DATA.model_energies),
    target_energies=np.array(DATA.target_energies),
    model_forces=np.array(DATA.model_forces),
    target_forces=np.array(DATA.target_forces)
)

# %% [markdown]
# # ... And Resume Here

# %%
data_smooth = np.load(f"data_samples_{MODEL.lower()}.npz")
bg_smooth = np.load(f"bg_samples_{MODEL.lower()}.npz")

# %%
from matplotlib import pyplot as plt

# %%
data_mse = ((data_smooth["model_forces"] - data_smooth["target_forces"])**2).mean()
np.sqrt(data_mse)
# Out:
# 87.53129

# %%
bg_mse = ((bg_smooth["model_forces"] - bg_smooth["target_forces"])**2).mean()
np.sqrt(bg_mse)
# Out:
# 139.5082

# %%
def plot_energies(ax, d):
    md_energies = d["target_energies"].flatten()
    sample_energies = d["model_energies"].flatten()
    #md_energies -= md_energies.min()
    sample_energies -= (sample_energies.min() - md_energies.min())

    cut = max(np.percentile(sample_energies, 80), 20)

    # y-axis on the right
    ax2 = plt.twinx(ax)
    ax.get_yaxis().set_visible(False)

    ax2.hist(
        sample_energies, range=(-50, cut), bins=50, 
        density=False, label="Target", fc=(1.0, 0, 0, 0.6)
    )
    ax2.hist(
        md_energies, range=(-50, cut), bins=50, 
        density=False, label="Flow", fc=(0,0,0.8,0.2), lw=1, ec="black"
    )
    ax2.set_ylabel(f"Count   [#Samples / 10000]")
    ax2.legend()

# %%
data_smooth["target_energies"].min() - data_smooth["model_energies"].min()
# Out:
# 185.75807

# %%
bg_smooth["target_energies"].min() - bg_smooth["model_energies"].min()
# Out:
# 187.85982

# %%
from bgforces.ala2.plot import plot_phi_psi
from scipy.stats import gaussian_kde

# %%
fig, axes = plt.subplots(2,3,figsize=(8,4.5), sharex="col")
fig.tight_layout()

plot_phi_psi(axes[0,0], torch.tensor(data_smooth["samples"]), data.dataset.system)
text1 = axes[0,0].text(-6, 0, "TEST SET (MD)", rotation=90, fontsize=12, va="center")
plot_phi_psi(axes[1,0], torch.tensor(bg_smooth["samples"]), data.dataset.system)
text2 = axes[1,0].text(-6, 0, "BG SAMPLES", rotation=90, fontsize=12, va="center")

ax = axes[0,1]
ax.scatter(data_smooth["model_forces"], data_smooth["target_forces"], s=0.1, color="blue")
ax.set_xlim(-2800., 2800.)
ax.set_ylim(-2800., 2800.)
ax.set_ylabel("Flow Forces [$k_B T$/nm]", labelpad=-60)

ax = axes[1,1]
ax.scatter(bg_smooth["model_forces"], bg_smooth["target_forces"], s=0.1, color="red")
ax.set_xlim(-2800., 2800.)
ax.set_ylim(-2800., 2800.)
ax.set_xlabel("Target Forces [$k_B T$/nm]")
ax.set_ylabel("Flow Forces [$k_B T$/nm]", labelpad=-60)

plot_energies(axes[0,2], data_smooth)
plot_energies(axes[1,2], bg_smooth)
axes[1,2].set_xlabel("Energy   [$k_B T$]")

fig.savefig(f"{MODEL.lower()}_bg.png", dpi=360, extra_bbox_agents=(text1, text2), bbox_inches="tight")
fig.savefig(f"{MODEL.lower()}_bg.pdf", dpi=360, extra_bbox_agents=(text1, text2), bbox_inches="tight")
# Out:
# /tmp/ipykernel_17201/211534222.py:26: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "extra_bbox_agents" which is no longer supported as of 3.3 and will become an error in 3.6
#   fig.savefig(f"{MODEL.lower()}_bg.png", dpi=360, extra_bbox_agents=(text1, text2), bbox_inches="tight")
# /tmp/ipykernel_17201/211534222.py:27: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "extra_bbox_agents" which is no longer supported as of 3.3 and will become an error in 3.6
#   fig.savefig(f"{MODEL.lower()}_bg.pdf", dpi=360, extra_bbox_agents=(text1, text2), bbox_inches="tight")

# %%
print("NLL = " + str(data_smooth["model_energies"].mean()))
print("FME (1e4) = " + str(((data_smooth["model_forces"] - data_smooth["target_forces"])**2).mean()/1e4) )
print("KLD = " + str(loaded._kld_for_samples(1000).item()))
# Out:
# NLL = -210.42924
# FME (1e4) = 0.766172705078125
# tensor(5.9697, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.0723, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(10.0552, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.8137, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(4.6306, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-2.8970, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(0.8453, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-1.6257, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# tensor(10.2499, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.1274, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# /home/sonic/anaconda3/envs/B_spline_flows_codeopt/lib/python3.8/site-packages/torch/_tensor.py:1104: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the .grad field to be populated for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations. (Triggered internally at  /opt/conda/conda-bld/pytorch_1646755903507/work/build/aten/src/ATen/core/TensorBody.h:475.)
#   return self._grad
# tensor(10.1392, dtype=torch.float64, grad_fn=<MaxBackward1>) tensor(-3.7719, dtype=torch.float64, grad_fn=<MinBackward1>)
# None
# KLD = 195.5601043701172
